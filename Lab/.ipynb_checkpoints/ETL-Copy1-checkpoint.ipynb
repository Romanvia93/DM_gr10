# %%
import xlrd
import MySQLdb

# %%
# 1. Establish a MySQL connection
database = MySQLdb.connect (host="localhost", user = "root", passwd = "1234", db = "dm_course_v3")

# # 2. Open the workbook and define the worksheet
# book = xlrd.open_workbook("Sample - Superstore - cleaned.xls")

# %% [markdown]
# ### Segment

# %%
# 1. Open the workbook and define the worksheet
sheet = book.sheet_by_name("segment")

# 2. Get the cursor, which is used to traverse the database, line by line
cursor = database.cursor()

# %%
# 3, Create the INSERT INTO sql query
query = """INSERT INTO segment (Segment, segment_id) VALUES (%s, %s)"""

# 4. Create a For loop to iterate through each row in the XLS file, starting at row 2 to skip the headers
for r in range(1, sheet.nrows):
    if sheet.cell(r,0).value != '':
        col_name_0 = sheet.cell(r,0).value
        col_name_1  = int(sheet.cell(r,1).value)


        # Assign values from each row
        values = (col_name_0, col_name_1)
        print(values)
        # Execute sql Query
        cursor.execute(query, values)
    else:
        pass

# Close the cursor
cursor.close()
# Commit the transaction
database.commit()
# Close the database connection
database.close()

# 5. Status
print('ETL - copleted')
# Out:
# ('Consumer', 1)
# ('Corporate', 2)
# ('Home Office', 3)
# ETL - copleted

# %% [markdown]
# ### Product

# %%
# 1. Open the workbook and define the worksheet
sheet = book.sheet_by_name("product")

# 2. Get the cursor, which is used to traverse the database, line by line
cursor = database.cursor()

# %%
# 3, Create the INSERT INTO sql query
query = """INSERT INTO product ('Product ID', 'Product Name', sub_category_id) VALUES (%s, %s, %s)"""

# 4. Create a For loop to iterate through each row in the XLS file, starting at row 2 to skip the headers
for r in range(1, sheet.nrows):
    col_name_0 = sheet.cell(r,0).value
    col_name_1  = sheet.cell(r,1).value
    col_name_2  = int(sheet.cell(r,2).value)

    
    # Assign values from each row
    values = (col_name_0, col_name_1, col_name_2)
    print(values)

    # Execute sql Query
    cursor.execute(query, values)

# Close the cursor
cursor.close()
# Commit the transaction
database.commit()
# Close the database connection
database.close()

# 5. Status
print('ETL - copleted')

# %% [markdown]
# ### City

# %%
# 1. Open the workbook and define the worksheet
sheet = book.sheet_by_name("city")

# 2. Get the cursor, which is used to traverse the database, line by line
cursor = database.cursor()

# %%
# 3, Create the INSERT INTO sql query
query = """INSERT INTO city (City, Country_Region, State, Region, city_id) VALUES (%s, %s, %s, %s, %s)"""

# 4. Create a For loop to iterate through each row in the XLS file, starting at row 2 to skip the headers
for r in range(1, sheet.nrows):
    if sheet.cell(r,0).value != '':
        col_name_0 = sheet.cell(r,0).value
        col_name_1  = sheet.cell(r,1).value
        col_name_2  = sheet.cell(r,2).value
        col_name_3  = sheet.cell(r,3).value
        col_name_4  = int(sheet.cell(r,4).value)
        
        # Assign values from each row
        values = (col_name_0, col_name_1, col_name_2, col_name_3, col_name_4)
        print(values)

        # Execute sql Query
        cursor.execute(query, values)
    else:
        pass

# Close the cursor
cursor.close()
# Commit the transaction
database.commit()
# Close the database connection
database.close()

# 5. Status
print('ETL - copleted')
# Out:
# ('Aberdeen', 'United States', 'South Dakota', 'Central', 1)
# ('Abilene', 'United States', 'Texas', 'Central', 2)
# ('Akron', 'United States', 'Ohio', 'East', 3)
# ('Albuquerque', 'United States', 'New Mexico', 'West', 4)
# ('Alexandria', 'United States', 'Virginia', 'South', 5)
# ('Allen', 'United States', 'Texas', 'Central', 6)
# ('Allentown', 'United States', 'Pennsylvania', 'East', 7)
# ('Altoona', 'United States', 'Pennsylvania', 'East', 8)
# ('Amarillo', 'United States', 'Texas', 'Central', 9)
# ('Anaheim', 'United States', 'California', 'West', 10)
# ('Andover', 'United States', 'Massachusetts', 'East', 11)
# ('Ann Arbor', 'United States', 'Michigan', 'Central', 12)
# ('Antioch', 'United States', 'California', 'West', 13)
# ('Apopka', 'United States', 'Florida', 'South', 14)
# ('Apple Valley', 'United States', 'California', 'West', 15)
# ('Apple Valley', 'United States', 'Minnesota', 'Central', 16)
# ('Appleton', 'United States', 'Wisconsin', 'Central', 17)
# ...

# %% [markdown]
# ### Adress

# %%
name_table = "adress"

# 1. Open the workbook and define the worksheet
sheet = book.sheet_by_name(f"{name_table}")

# 2. Get the cursor, which is used to traverse the database, line by line
cursor = database.cursor()

# %%
# 3, Create the INSERT INTO sql query
query = f"""INSERT INTO {name_table} (Postal_Code, city_id) VALUES (%s, %s)"""

# 4. Create a For loop to iterate through each row in the XLS file, starting at row 2 to skip the headers
for r in range(1, sheet.nrows):
    if sheet.cell(r,0).value != '':
        col_name_0 = int(sheet.cell(r,0).value)
        col_name_1  = int(sheet.cell(r,1).value)
        
        # Assign values from each row
        values = (col_name_0, col_name_1)
        print(values)

        # Execute sql Query
        cursor.execute(query, values)
    else:
        pass

# Close the cursor
cursor.close()
# Commit the transaction
database.commit()
# Close the database connection
database.close()

# 5. Status
print('ETL - copleted')
# Out:
# (1040, 231)
# (1453, 293)
# (1752, 326)
# (1810, 11)
# (1841, 287)
# (1852, 312)
# (1915, 44)
# (2038, 182)
# (2138, 72)
# (2148, 316)
# (2149, 165)
# (2151, 458)
# (2169, 445)
# (2740, 371)
# (2886, 568)
# (2895, 593)
# (2908, 441)
# (2920, 122)
# (3060, 368)
# (3301, 112)
# (3820, 141)
# (4240, 295)
# (4401, 34)
# (6010, 59)
# (6040, 317)
# (6360, 387)
# (6450, 335)
# (6457, 340)
# (6460, 342)
# (6484, 513)
# (6708, 570)
# (6824, 168)
# (7002, 36)
# (7011, 96)
# (7017, 148)
# (7036, 297)
# (7050, 399)
# (7055, 416)
# (7060, 429)
# (7090, 579)
# (7109, 40)
# (7501, 417)
# (7601, 211)
# (7960, 358)
# (8302, 57)
# (8360, 563)
# (8401, 25)
# (8701, 277)
# (8861, 423)
# (8901, 372)
# (10009, 375)
# (10011, 375)
# (10024, 375)
# (10035, 375)
# (10550, 361)
# (10701, 594)
# (10801, 374)
# (11520, 184)
# (11550, 220)
# (11561, 304)
# (11572, 392)
# (11757, 298)
# (12180, 552)
# (13021, 27)
# (13440, 471)
# (13501, 559)
# (13601, 572)
# (14215, 64)
# (14304, 379)
# (14609, 466)
# ...

# %% [markdown]
# ### Customer

# %%
name_table = "customer"

# 1. Open the workbook and define the worksheet
sheet = book.sheet_by_name(f"{name_table}")

# 2. Get the cursor, which is used to traverse the database, line by line
cursor = database.cursor()

# %%
# 3, Create the INSERT INTO sql query
query = f"""INSERT INTO {name_table} (Customer_ID, Customer_Name, segment_id, Postal_Code) VALUES (%s, %s, %s, %s)"""

# 4. Create a For loop to iterate through each row in the XLS file, starting at row 2 to skip the headers
for r in range(1, sheet.nrows):
    if sheet.cell(r,0).value != '':
        col_name_0 = sheet.cell(r,0).value
        col_name_1  = sheet.cell(r,1).value
        col_name_2  = int(sheet.cell(r,2).value)
        col_name_3  = int(sheet.cell(r,3).value)
        
        # Assign values from each row
        values = (col_name_0, col_name_1,col_name_2, col_name_3)
        print(values)

        # Execute sql Query
        cursor.execute(query, values)
    else:
        pass

# Close the cursor
cursor.close()
# Commit the transaction
database.commit()
# Close the database connection
database.close()

# 5. Status
print('ETL - copleted')
# Out:
# ('AA-10315', 'Alex Avila', 1, 10011)
# ('AA-10315', 'Alex Avila', 1, 78664)
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3900\3785916056.py in <module>
#      15
#      16         # Execute sql Query
# ---> 17         cursor.execute(query, values)
#      18     else:
#      19         pass
#
# ~\anaconda3\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     204
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#     208
#
# ~\anaconda3\lib\site-packages\MySQLdb\cursors.py in _query(self, q)
#     317         db = self._get_db()
#     318         self._result = None
# --> 319         db.query(q)
#     320         self._do_get_result(db)
#     321         self._post_get_result()
#
# ...
